# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/Anne/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Anne/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from requests) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Anne/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from requests) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/Anne/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from requests) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Anne/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages (from requests) (3.3)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.8 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
from IPython.display import display, Image

# %% [markdown]
# # API functions

# %%
# Function to extract 'title' from categories
def extract_titles(categories):
    return [category['title'] for category in categories]

# %%
#Function to only exctract the first addresse line
def extract_addresse(location):
    return location.get('address1', '')

# %%
#Hauptfunktion 1 um informationen vom API zu holen 
def get_restaurants_location_clean(location):
    #calling the API    
    url = "https://api.yelp.com/v3/businesses/search"
    headers = {
        "Authorization": "Bearer EN2FsqhUn487c-Hh4FeZGlJKk9i6bCC1kW45fmc4TQx1zw2sQ8CNGM57G3olkT4OYLcDtHHU_PVyJKaIIboLtnlVledeI6-UAwAor6xhNLIZxxqQ-EgExHGMXDAlZnYx"
    }
    params = {
        "term": "restaurants",
        "location": f"{location}"
    }
    response = requests.get(url, headers=headers, params=params)
    json_testing = response.json()
    
    #transforming the Json content from the API into a data frame 
    df_testing = pd.DataFrame(json_testing["businesses"])
    
    #only getting the columns for name, categories and location
    nice_format = df_testing[["name", "categories", "location"]]
    
    # Applying the function to the 'categories' column
    nice_format['category_titles'] = nice_format['categories'].apply(extract_titles)
    
    # Applying the function to the 'categories' column
    nice_format['location'] = nice_format['location'].apply(extract_addresse)
    
    #removing the brackets from the category titles, by first turing the column into strings and then using the strip 
    # function to remove it. 
    nice_format["category_titles"] = nice_format["category_titles"].astype(str)
    nice_format["category_titles"] = nice_format["category_titles"].str.strip('[')
    nice_format["category_titles"] = nice_format["category_titles"].str.strip(']')
    nice_format["category_titles"] = nice_format["category_titles"].str.strip("''")
    
    #dropping the categories column, since we extracted the necessariy information and put it into the category_titles column, that we made
    nice_format_1 = nice_format.drop('categories', axis=1)
    
    
    return nice_format_1

# %%
#Hauptfunktion 2 um informationen vom API zu holen 
def get_restaurants_location(location):
    #calling the API     
    url = "https://api.yelp.com/v3/businesses/search"
    headers = {
        "Authorization": "Bearer EN2FsqhUn487c-Hh4FeZGlJKk9i6bCC1kW45fmc4TQx1zw2sQ8CNGM57G3olkT4OYLcDtHHU_PVyJKaIIboLtnlVledeI6-UAwAor6xhNLIZxxqQ-EgExHGMXDAlZnYx"
    }
    params = {
        "term": "restaurants",
        "location": f"{location}"
    }
    response = requests.get(url, headers=headers, params=params)
    json_testing = response.json()
    
    #transforming the Json content from the API into a data frame 
    df_testing = pd.DataFrame(json_testing["businesses"])
    
    #making a new datafrme with these columns, so we have a dataframe with all the information we need
    business_df = df_testing[["id", "name", "image_url", "categories", "location"]]  
    
    return business_df

# %%
#funktion 1 callen
locations = get_restaurants_location("St.Gallen")

# %%
#gettting locations dataframe 
locations
# Out:
#                         id                                           name  \
# 0   OBeg8ZM_n8deI6Rvur_oDw                                     Fondue Alp
# 1   _R88k2GMY7JNkbgof2m61w                          Restaurant Marktplatz
# 2   _5NxStVC1etwduMQKxM6eA                                     Gartenhaus
# 3   X-g716_f0A5bSvMTqItiMw                         Cafe Restaurant pärkli
# 4   -k4sLKc2FtgYA5QODNNlXg                       Restaurant Fondue-Beizli
# 5   8wZBRSOA8m8v5Z-Zwbp09Q                                Restaurant Holi
# 6   q7ffEkdcjZ6dVjYZGq4HFQ  Restaurant Kastanienhof In Der Militärkantine
# 7   PvXhwETK9JeFbrtvBjFdVA                                     La Taverna
# 8   j74pPpah9mlJFMFvlJABPw                                Japan House Edo
# 9   IRj9mK71b82bp-V92NN1lw                                Drahtseilbähnli
# 10  HZ8oLaETBSMa1AsupLLidg                                     focacceria
# 11  1gGmUYiazbMjGKo7RM4vmQ                           Restaurant Stickerei
# 12  szbeUIMkCIM3JETgI49I1w                      Restaurant am Gallusplatz
# 13  xU3iZOl0fCnd-MHW1ix4Uw                 Restaurant Waffenplatz Winkeln
# 14  Yz2AJe0rJkrsiAucMfX6qg                   Restaurant Pizzeria Schwanen
# 15  tj9pspmglMtUXwzZqTunjA                            Restaurant Jägerhof
# 16  PTZgQgwXzeQ66GMpgUh3Rw          China-Restaurant zum goldenen Drachen
# 17  vHJe8rAe0cPyugyuIT8nZA                              Pizzeria la Bocca
# 18  eaRZfnn74x4SYbP8FCOApQ                                         Nektar
# 19  4zNDEYAlLj3wabGW9ch6tg                           Zum Goldenen Schäfli
#
#                                             image_url  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/SbcPg7...
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/kTLBGx...
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/U0Fc2m...
# 3   https://s3-media4.fl.yelpcdn.com/bphoto/o8vmBC...
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/3N_oGB...
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/dfKsPx...
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/rBFQct...
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/6d5ADC...
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/bG32kB...
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/9YQ08g...
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/Ft_ycR...
# 11  https://s3-media3.fl.yelpcdn.com/bphoto/KVjK7Z...
# 12  https://s3-media4.fl.yelpcdn.com/bphoto/weGHRf...
# 13  https://s3-media1.fl.yelpcdn.com/bphoto/CCEQGo...
# 14  https://s3-media4.fl.yelpcdn.com/bphoto/rg9B5D...
# 15  https://s3-media3.fl.yelpcdn.com/bphoto/rxGQRA...
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/nAj22I...
# 17  https://s3-media4.fl.yelpcdn.com/bphoto/Ku37w0...
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/Jlhuxf...
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/Yk9OZx...
#
#                                            categories  \
# 0   [{'alias': 'swissfood', 'title': 'Swiss Food'}...
# 1     [{'alias': 'swissfood', 'title': 'Swiss Food'}]
# 2     [{'alias': 'swissfood', 'title': 'Swiss Food'}]
# 3   [{'alias': 'lebanese', 'title': 'Lebanese'}, {...
# 4     [{'alias': 'swissfood', 'title': 'Swiss Food'}]
# 5            [{'alias': 'indpak', 'title': 'Indian'}]
# 6     [{'alias': 'swissfood', 'title': 'Swiss Food'}]
# 7   [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 8        [{'alias': 'japanese', 'title': 'Japanese'}]
# 9   [{'alias': 'swissfood', 'title': 'Swiss Food'}...
# 10  [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 11         [{'alias': 'burgers', 'title': 'Burgers'}]
# 12    [{'alias': 'swissfood', 'title': 'Swiss Food'}]
# 13    [{'alias': 'swissfood', 'title': 'Swiss Food'}]
# 14             [{'alias': 'pizza', 'title': 'Pizza'}]
# 15  [{'alias': 'restaurants', 'title': 'Restaurant...
# 16         [{'alias': 'chinese', 'title': 'Chinese'}]
# 17             [{'alias': 'pizza', 'title': 'Pizza'}]
# 18  [{'alias': 'mediterranean', 'title': 'Mediterr...
# 19    [{'alias': 'swissfood', 'title': 'Swiss Food'}]
#
#                                              location
# 0   {'address1': 'Neugasse 46', 'address2': '', 'a...
# 1   {'address1': 'Neugasse 2', 'address2': '', 'ad...
# 2   {'address1': 'Geltenwilenstrasse 8', 'address2...
# 3   {'address1': 'Oberer Graben 12', 'address2': N...
# 4   {'address1': 'Brühlgasse 26', 'address2': None...
# 5   {'address1': 'St. Jakob Strasse 87', 'address2...
# 6   {'address1': 'Kreuzbleicheweg 2', 'address2': ...
# 7   {'address1': 'St. Leonhard-Strasse 12', 'addre...
# 8   {'address1': 'Engelgasse 11 - 15', 'address2':...
# 9   {'address1': 'St. Georgenstrasse 3', 'address2...
# 10  {'address1': 'Metzgergasse 22', 'address2': ''...
# 11  {'address1': 'Oberer Graben 44', 'address2': N...
# 12  {'address1': 'Gallusstrasse 24', 'address2': N...
# 13  {'address1': 'Zürcher Strasse 495', 'address2'...
# 14  {'address1': 'Webergasse 23', 'address2': '', ...
# 15  {'address1': 'Brühlbleichestrasse 11', 'addres...
# 16  {'address1': 'Rosenbergstrasse 55', 'address2'...
# 17  {'address1': 'Rorschacher Strasse 154', 'addre...
# 18  {'address1': 'Geltenwilenstrasse 16', 'address...
# 19  {'address1': 'Metzgergasse 5', 'address2': Non...

# %%
#function 2 callen
locations_clean = get_restaurants_location_clean("St.Gallen")
# Out:
# /var/folders/my/y91gfk8x16z6m5vl39f53nn40000gp/T/ipykernel_94367/686362269.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nice_format['category_titles'] = nice_format['categories'].apply(extract_titles)
# /var/folders/my/y91gfk8x16z6m5vl39f53nn40000gp/T/ipykernel_94367/686362269.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nice_format['location'] = nice_format['location'].apply(extract_addresse)
# /var/folders/my/y91gfk8x16z6m5vl39f53nn40000gp/T/ipykernel_94367/686362269.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nice_format["category_titles"] = nice_format["category_titles"].astype(str)
# /var/folders/my/y91gfk8x16z6m5vl39f53nn40000gp/T/ipykernel_94367/686362269.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nice_format["category_titles"] = nice_format["category_titles"].str.strip('[')
# /var/folders/my/y91gfk8x16z6m5vl39f53nn40000gp/T/ipykernel_94367/686362269.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nice_format["category_titles"] = nice_format["category_titles"].str.strip(']')
# /var/folders/my/y91gfk8x16z6m5vl39f53nn40000gp/T/ipykernel_94367/686362269.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nice_format["category_titles"] = nice_format["category_titles"].str.strip("''")

# %%
#getting locations clean data frame 
locations_clean
# Out:
#                                              name                 location  \
# 0                                      Fondue Alp              Neugasse 46
# 1                           Restaurant Marktplatz               Neugasse 2
# 2                                      Gartenhaus     Geltenwilenstrasse 8
# 3                          Cafe Restaurant pärkli         Oberer Graben 12
# 4                        Restaurant Fondue-Beizli            Brühlgasse 26
# 5                                 Restaurant Holi     St. Jakob Strasse 87
# 6   Restaurant Kastanienhof In Der Militärkantine        Kreuzbleicheweg 2
# 7                                      La Taverna  St. Leonhard-Strasse 12
# 8                                 Japan House Edo       Engelgasse 11 - 15
# 9                                 Drahtseilbähnli     St. Georgenstrasse 3
# 10                                     focacceria          Metzgergasse 22
# 11                           Restaurant Stickerei         Oberer Graben 44
# 12                      Restaurant am Gallusplatz         Gallusstrasse 24
# 13                 Restaurant Waffenplatz Winkeln      Zürcher Strasse 495
# 14                   Restaurant Pizzeria Schwanen            Webergasse 23
# 15                            Restaurant Jägerhof   Brühlbleichestrasse 11
# 16          China-Restaurant zum goldenen Drachen      Rosenbergstrasse 55
# 17                              Pizzeria la Bocca  Rorschacher Strasse 154
# 18                                         Nektar    Geltenwilenstrasse 16
# 19                           Zum Goldenen Schäfli           Metzgergasse 5
#
#                      category_titles
# 0               Swiss Food', 'Fondue
# 1                         Swiss Food
# 2                         Swiss Food
# 3                Lebanese', 'Buffets
# 4                         Swiss Food
# 5                             Indian
# 6                         Swiss Food
# 7                   Italian', 'Pizza
# 8                           Japanese
# 9   Swiss Food', 'Breakfast & Brunch
# 10              Italian', 'Fast Food
# 11                           Burgers
# 12                        Swiss Food
# 13                        Swiss Food
# 14                             Pizza
# 15                       Restaurants
# 16                           Chinese
# 17                             Pizza
# 18                     Mediterranean
# 19                        Swiss Food

# %% [markdown]
# # getting images

# %%
#Built a function to display the pictures eith by their id or name 
def get_picture_of_restaurant(df, restaurant_id=None, restaurant_name=None):
    if restaurant_id:
        matching_rows = df[df['id'] == restaurant_id]
    elif restaurant_name:
        matching_rows = df[df['name'].str.contains(restaurant_name, case=False, na=False)]
    else:
        return "No restaurant specified!"

    #if there are no matches, both id or name it will return this
    if matching_rows.empty:
        print("No matching restaurant found.")
    else:
        for _, row in matching_rows.iterrows():
            display(Image(url=row['image_url']))

# %%
#returning pictures of restsuarants based on id
byid = get_picture_of_restaurant(locations, restaurant_id='OBeg8ZM_n8deI6Rvur_oDw')
# Out:
# <img src="https://s3-media1.fl.yelpcdn.com/bphoto/SbcPg7yH-N5y7thq4_EjBQ/o.jpg"/>

# %%
#returning pictures of restsuarants based on name
name = get_picture_of_restaurant(locations, restaurant_name='focacceria')
# Out:
# <img src="https://s3-media2.fl.yelpcdn.com/bphoto/Ft_ycRu5vWCqIBLlZq9TJg/o.jpg"/>

# %% [markdown]
# # Database

# %%
# Define the DataFrame with specific types to avoid type issues
database = pd.DataFrame({
    'id': pd.Series(dtype='int'),
    'restaurant': pd.Series(dtype='str'),
    'comment': pd.Series(dtype='str'),
    'name': pd.Series(dtype='str'),
    'rating': pd.Series(dtype='str'),
    'ID': pd.Series(dtype='str')
})

# %%
def add_entry_to_df():
    global database  # Reference the global DataFrame

    # Generate the next ID
    next_id = database['id'].max() + 1 if not database.empty else 1
    
    # Collect user inputs
    restaurant = input("Enter the restaurant name: ")
    comment = input("Enter your comment: ")
    name = input("Enter your name: ")
    rating = input("How do you rate this restaurant from 5: ")
    ID = input("Enter restaurant ID: ")

    # Create a dictionary with the new data
    new_data = {
        'id': next_id,
        'restaurant': restaurant,
        'comment': comment,
        'name': name, 
        'rating': rating,
        'ID': ID
    }

    # Append new data to the global DataFrame
    new_data_df = pd.DataFrame([new_data])
    database = pd.concat([database, new_data_df], ignore_index=True)

# %%
#adding stuff to the made dataframe with the function
add_entry_to_df()

# %%
#calling the database
database
# Out:
#    id  restaurant        comment  name rating   ID
# 0   1  Foccaceria  amazing food!  nina      5  789

# %%
def only_restaurant(name_restaurant):
    return database.loc[database[restaurant] == f"{name_restaurant}]

# %%
def specific_person(person_name):
